# %%
from kaggle_secrets import UserSecretsClient
KEY = UserSecretsClient().get_secret("WANDB_API_KEY")

# %%
# %cp -r /kaggle/input/datasets/glitchr/tredence-analytics-ai-intern/* /kaggle/working/
# !ls /kaggle/working/
# Out:
# configs  README.md  requirements.txt  src  tests  train.py

# %%
# !python train.py --epochs 30 --lambdas 0.1 0.5 1.0 --wandb-key {KEY}
# Out:
# INFO      root  08:13:56  INFO      root  Logging initialised  |  file → logs/run_lambdas_0.1_0.5_1.0_20260424_081356.log
# INFO      __main__  08:13:56  INFO      __main__  ============================================================
# INFO      __main__  08:13:56  INFO      __main__  Self-Pruning Neural Network  —  CIFAR-10
# INFO      __main__  08:13:56  INFO      __main__  ============================================================
# INFO      __main__  08:13:56  INFO      __main__  Config: epochs=100  lr=1e-03  batch=256  λ=[0.1, 0.5, 1.0]
# INFO      __main__  08:13:57  INFO      __main__  Device: cuda
# INFO      src.data  08:13:58  INFO      src.data  CIFAR-10 loaded | train=50000  test=10000  batch_size=256
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# ...

# %%
# !ls
# Out:
# configs  logs	  README.md	    src    train.py
# data	 outputs  requirements.txt  tests  wandb
